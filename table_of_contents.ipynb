# %% [markdown]
# <center><h1>Lie Groups in Robotics and Control</h1></center>
# <p>
#  <p>
#
# ## Table of Contents
#
# [**Preface**](00-Preface.ipynb)
#
# Motivation behind writing the book. How to download and read the book. Requirements for IPython Notebook and Python. github links.
#
# [**Chapter 1: Preliminary Notation**](Chap-01-Notation.ipynb)
# This chapter provides definitions of groups and algebras, and defines other notation that will be used throughout the book.
#
# [**Chapter 2: $S^1$ - Kinematics, Control, Estimation**](Chap-02-S1.ipynb)
#
# This chapter describes kinematic equations on the unit circle $S^1$.  Controllers and estimators on the unit circle are also derived and demonstrated.
#
# [**Chapter 3: $SE(2)$ - Kinematics, Control, Estimation**](Chap-03-SE2.ipynb)
#
# [**Chapter 4: $SO(3)$ - Kinematics, Control, Estimation**](Chap-04-SO3.ipynb)
#
# [**Chapter 5: $S^3$ - Kinematics, Control, Estimation**](Chap-05-SO3.ipynb)
#
# [**Chapter 6: $SE(3)$ - Kinematics, Control, Estimation**](Chap-06-SE3.ipynb)
#
# [**Chapter 7: $SL(3)$ - Kinematics, Control, Estimation**](Chap-07-SL3.ipynb)
#
#
# ## Supporting Papers and Websites
#
# - J. M. Selig, Lie Groups and Lie Algebras in Robotics,
# https://pdfs.semanticscholar.org/ec46/01c4bf6a8c4072bc16de38766c6d596e0e67.pdf
#
# - Ethan Eade, Lie Groups in Computer Vision,
# http://ethaneade.com/lie_groups.pdf
#
# - Oren Freifeld, Methods in Computer Vision: Introduction to Matrix Lie Groups,
# https://www.cs.bgu.ac.il/~mcv172/wiki.files/LecLie.pdf
#
#
#
#
#
# ## Supporting Notebooks
#
#
#
# ## Github repository
# https://github.com/byu-magicc/lie_groups
#
# Viewer only: http://nbviewer.jupyter.org/github/byu-magicc/lie_groups/blob/master/table_of_contents.ipynb
#
# This Jupyter book is mimicking the style of the following book:
#
# http://github.com/rlabbe/Kalman-and-Bayesian-Filters-in-Python

# %%
#format the book
from book_format import load_style
load_style()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Lora');
#
# .CodeMirror pre {
#     font-family: 'Source Code Pro', Consolas, monocco, monospace;
# }
#     div.cell{
#         //width: 950px;
#         margin-left: 0% !important;
#         margin-right: auto;
#     }
#     div.text_cell_render{
#         font-family: 'Lora';
#         line-height: 125%;
#         font-size: 100%;
#         text-align: justify;
#         text-justify:inter-word;
#     }
#     div.text_cell code {
#         background: transparent;
#         color: #000000;
#         font-weight: 400;
#         font-size: 11pt;
#         font-family:  'Source Code Pro', Consolas, monocco, monospace;
#    }
#     h1 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
# 	}
#
#     div.input_area {
#         background: #F6F6F9;
#         border: 1px solid #586e75;
#     }
#
#     .text_cell_render h1 {
# ...
